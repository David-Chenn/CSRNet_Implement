# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !pwd
# Out:
# /content

# %%
cd /content/drive/My\ Drive/Colab Notebooks
# Out:
# /content/drive/My Drive/Colab Notebooks

# %%
#!/usr/bin/env python
# coding: utf-8

# In[1]:


import h5py
import scipy.io as io
import PIL.Image as Image
import numpy as np
import os
import glob
from matplotlib import pyplot as plt
from scipy.ndimage.filters import gaussian_filter 
import scipy
import json
import torchvision.transforms.functional as F
from matplotlib import cm as CM
#from image import *
from model import CSRNet
import torch
get_ipython().run_line_magic('matplotlib', 'inline')


# In[2]:


from torchvision import datasets, transforms
transform=transforms.Compose([
                       transforms.ToTensor(),transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                     std=[0.229, 0.224, 0.225]),
                   ])


# In[6]:


root = '/content/drive/My Drive/Colab Notebooks/ShanghaiTech_Crowd_Counting_Dataset'


# In[7]:


#now generate the ShanghaiA's ground truth
part_A_train = os.path.join(root,'part_A_final/train_data','images')
part_A_test = os.path.join(root,'part_A_final/test_data','images')
part_B_train = os.path.join(root,'part_B_final/train_data','images')
part_B_test = os.path.join(root,'part_B_final/test_data','images')
path_sets = [part_A_test]

# In[8]:


img_paths = []
for path in path_sets:
    for img_path in glob.glob(os.path.join(path, '*.jpg')):
        os.path.join(path, '*.jpg')
        img_paths.append(img_path)
print(img_paths)

# In[9]:


np.zeros([3,2])


# In[10]:


model = CSRNet()


# In[11]:


model = model.cuda()


# In[12]:


checkpoint = torch.load('best55epochmodel_best.pth.tar')


# In[ ]:


model.load_state_dict(checkpoint['state_dict'])


# In[ ]:


mae = 0
for i in range(len(img_paths)):
    img = 255.0 * F.to_tensor(Image.open(img_paths[i]).convert('RGB'))

    img = img.cuda()
    img = transform(Image.open(img_paths[i]).convert('RGB')).cuda()
    gt_file = h5py.File(img_paths[i].replace('.jpg','.h5').replace('images','ground_truth'),'r')
    groundtruth = np.asarray(gt_file['density'])
    output = model(img.unsqueeze(0))
   #npoutput = output.numpy()
   #########0529####
    mae += abs(output.detach().cpu().sum().numpy()-np.sum(groundtruth))
    print(i,mae)
    print('gtrtuth',np.sum(groundtruth))
    print('count',output.detach().cpu().sum())
    ############0529######
print(mae/len(img_paths))


# In[ ]:'''
# Out:
# ['/content/drive/My Drive/Colab Notebooks/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_106.jpg', '/content/drive/My Drive/Colab Notebooks/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_107.jpg', '/content/drive/My Drive/Colab Notebooks/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_11.jpg', '/content/drive/My Drive/Colab Notebooks/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_101.jpg', '/content/drive/My Drive/Colab Notebooks/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_102.jpg', '/content/drive/My Drive/Colab Notebooks/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_103.jpg', '/content/drive/My Drive/Colab Notebooks/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_1.jpg', '/content/drive/My Drive/Colab Notebooks/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_100.jpg', '/content/drive/My Drive/Colab Notebooks/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_109.jpg', '/content/drive/My Drive/Colab Notebooks/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_104.jpg', '/content/drive/My Drive/Colab Notebooks/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_110.jpg', '/content/drive/My Drive/Colab Notebooks/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_108.jpg', '/content/drive/My Drive/Colab Notebooks/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_105.jpg', '/content/drive/My Drive/Colab Notebooks/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_10.jpg', '/content/drive/My Drive/Colab Notebooks/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_126.jpg', '/content/drive/My Drive/Colab Notebooks/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_115.jpg', '/content/drive/My Drive/Colab Notebooks/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_117.jpg', '/content/drive/My Drive/Colab Notebooks/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_114.jpg', '/content/drive/My Drive/Colab Notebooks/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_111.jpg', '/content/drive/My Drive/Colab Notebooks/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_112.jpg', '/content/drive/My Drive/Colab Notebooks/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_113.jpg', '/content/drive/My Drive/Colab Notebooks/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_128.jpg', '/content/drive/My Drive/Colab Notebooks/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_118.jpg', '/content/drive/My Drive/Colab Notebooks/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_124.jpg', '/content/drive/My Drive/Colab Notebooks/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_119.jpg', '/content/drive/My Drive/Colab Notebooks/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_121.jpg', '/content/drive/My Drive/Colab Notebooks/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_116.jpg', '/content/drive/My Drive/Colab Notebooks/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_123.jpg', '/content/drive/My Drive/Colab Notebooks/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_122.jpg', '/content/drive/My Drive/Colab Notebooks/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_125.jpg', '/content/drive/My Drive/Colab Notebooks/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_12.jpg', '/content/drive/My Drive/Colab Notebooks/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_127.jpg', '/content/drive/My Drive/Colab Notebooks/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_120.jpg', '/content/d ...
# 0 91.9464111328125
# gtrtuth 1225.8102
# count tensor(1317.7566)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-bed4419088f3> in <module>()
#     100     img = transform(Image.open(img_paths[i]).convert('RGB')).cuda()
#     101     gt_file = h5py.File(img_paths[i].replace('.jpg','.h5').replace('images','ground_truth'),'r')
# --> 102     groundtruth = np.asarray(gt_file['density'])
#     103     output = model(img.unsqueeze(0))
#     104    #npoutput = output.numpy()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# /usr/local/lib/python3.6/dist-packages/h5py/_hl/group.py in __getitem__(self, name)
#     262                 raise ValueError("Invalid HDF5 object reference")
#     263         else:
# --> 264             oid = h5o.open(self.id, self._e(name), lapl=self._lapl)
#     265
#     266         otype = h5i.get_type(oid)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5o.pyx in h5py.h5o.open()
#
# KeyError: "Unable to open object (object 'density' doesn't exist)"
